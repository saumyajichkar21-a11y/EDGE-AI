# %%
import numpy as np

data = np.random.randn(5, 3)

# Task 1
print("Shape:", data.shape)

# Task 2
print("Column means:", np.mean(data, axis=0))

# Task 3
print("Max:", np.max(data))

# Task 4
mean = np.mean(data)
std = np.std(data)
normalized = (data - mean) / std
print("Normalized:\n", normalized)

# Task 5
print("Shape after normalize:", normalized.shape)
# Out:
# Shape: (5, 3)
# Column means: [-0.40296372  0.20216275  0.37154762]
# Max: 1.4386032367490456
# Normalized:
#  [[-1.62568035  0.05214761 -0.23676334]
#  [ 0.13723103 -0.19176009  1.87278706]
#  [-0.88841575 -0.19149932  1.4168951 ]
#  [ 0.91589001  1.3610297  -0.60770687]
#  [-1.65570593 -0.04555263 -0.31289623]]
# Shape after normalize: (5, 3)

# %%
import numpy as np

# 64 images, 784 pixels each
batch = np.random.randn(64, 784)

# Weight matrix of first layer
weights = np.random.randn(784, 128)

# Forward pass — one layer
output = np.matmul(batch, weights)
print("Output shape:", output.shape)
# Out:
# Output shape: (64, 128)

# %%
# 64 images through layer 1 — output shape (64, 128)
output = np.matmul(batch, weights)  # (64, 128)

# Bias — one per neuron, shape (128,)
bias = np.random.randn(128)

# Add bias to every image's output
result = output + bias  # broadcasting — (64, 128) + (128,) = (64, 128)
print(result.shape)
# Out:
# (64, 128)

# %%
import pandas as pd

# Series — one column
s = pd.Series([10, 20, 30, 40, 50])
print(s)
print(s.shape)  # (5,) — same as NumPy

# DataFrame — full table (rows + columns)
df = pd.DataFrame({
    'name':   ['Alice', 'Bob', 'Charlie', 'Diana'],
    'age':    [25, 30, 22, 28],
    'salary': [50000, 70000, 45000, 80000]
})

print(df)
print(df.shape)  # (4, 3) — 4 rows, 3 columns
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# (5,)
#       name  age  salary
# 0    Alice   25   50000
# 1      Bob   30   70000
# 2  Charlie   22   45000
# 3    Diana   28   80000
# (4, 3)

# %%
# 1. See first few rows — always run this first on any new dataset
print(df.head(2))

# 2. Basic stats — instant summary of every column
print(df.describe())

# 3. Select one column
print(df['age'])

# 4. Filter rows — only people above 25
print(df[df['age'] > 25])

# 5. Handle missing data — the most common real world problem
df2 = pd.DataFrame({
    'name':   ['Alice', 'Bob', 'Charlie', 'Diana'],
    'age':    [25, None, 22, 28],      # Bob's age is missing
    'salary': [50000, 70000, None, 80000]  # Charlie's salary missing
})

print("\nBefore filling missing:")
print(df2)

print("\nMissing value count:")
print(df2.isnull().sum())

print("\nAfter filling with mean:")
df2['age'] = df2['age'].fillna(df2['age'].mean())
df2['salary'] = df2['salary'].fillna(df2['salary'].mean())
print(df2)
# Out:
#     name  age  salary
# 0  Alice   25   50000
# 1    Bob   30   70000
#          age        salary
# count   4.00      4.000000
# mean   26.25  61250.000000
# std     3.50  16520.189668
# min    22.00  45000.000000
# 25%    24.25  48750.000000
# 50%    26.50  60000.000000
# 75%    28.50  72500.000000
# max    30.00  80000.000000
# 0    25
# 1    30
# 2    22
# 3    28
# Name: age, dtype: int64
#     name  age  salary
# 1    Bob   30   70000
# 3  Diana   28   80000
#
# Before filling missing:
#       name   age   salary
# 0    Alice  25.0  50000.0
# 1      Bob   NaN  70000.0
# 2  Charlie  22.0      NaN
# 3    Diana  28.0  80000.0
#
# Missing value count:
# name      0
# age       1
# salary    1
# dtype: int64
#
# After filling with mean:
#       name   age        salary
# 0    Alice  25.0  50000.000000
# 1      Bob  25.0  70000.000000
# 2  Charlie  22.0  66666.666667
# 3    Diana  28.0  80000.000000

# %%
import pandas as pd

# Load a real dataset directly from URL
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# Your tasks:
# 1. Print shape
print(df.shape)
# 2. Print first 5 rows
print(df.head(5))
# 3. Print missing value count per column
print(df.isnull().sum())
# 4. Drop the 'Cabin' column (too many missing values)
df=df.drop('Cabin',axis=1)
print(df.isnull().sum())
# 5. Fill missing 'Age' with median
df['Age']=df['Age'].fillna(df['Age'].median())
print(df.isnull().sum())
# 6. Print describe() on the cleaned dataframe
df.describe()
# Write and run all 6 tasks yourself
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
import matplotlib.pyplot as plt

epochs = list(range(1, 21))
train_loss = [0.95, 0.82, 0.71, 0.63, 0.57, 0.52, 0.48, 0.44,
              0.41, 0.38, 0.36, 0.34, 0.32, 0.31, 0.30, 0.29,
              0.28, 0.27, 0.265, 0.26]

val_loss = [0.98, 0.87, 0.79, 0.74, 0.71, 0.69, 0.68, 0.67,
            0.67, 0.68, 0.69, 0.71, 0.73, 0.76, 0.79, 0.82,
            0.86, 0.90, 0.94, 0.98]

plt.figure(figsize=(10, 5))
plt.plot(epochs, train_loss, label='Training Loss', color='blue')
plt.plot(epochs, val_loss, label='Validation Loss', color='red')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot 2 — Bar chart (feature importance, comparisons)
models = ['Original', 'Quantized', 'QAT', 'Pruned+Quant']
sizes  = [430.29, 112.39, 117.34, 84.3]
accuracy = [97.29, 96.8, 97.1, 94.40]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

ax1.bar(models, sizes, color=['#3498db', '#2ecc71', '#e74c3c', '#f39c12'])
ax1.set_title('Model Size Comparison (KB)')
ax1.set_ylabel('Size (KB)')

ax2.bar(models, accuracy, color=['#3498db', '#2ecc71', '#e74c3c', '#f39c12'])
ax2.set_title('Model Accuracy Comparison (%)')
ax2.set_ylabel('Accuracy (%)')
ax2.set_ylim(90, 100)

plt.tight_layout()
plt.show()

# %%
# Merging two dataframes — you'll need this
import pandas as pd

df1 = pd.DataFrame({'id': [1,2,3], 'name': ['A','B','C']})
df2 = pd.DataFrame({'id': [1,2,3], 'score': [90, 85, 92]})

merged = pd.merge(df1, df2, on='id')
print(merged)
# Out:
#    id name  score
# 0   1    A     90
# 1   2    B     85
# 2   3    C     92

# %%
pd.merge(df1, df2, on='id', how='inner')  # only matching rows
# Out:
#    id name  score
# 0   1    A     90
# 1   2    B     85
# 2   3    C     92

# %%
pd.merge(df1, df2, on='id', how='left')   # all df1 rows + matches
# Out:
#    id name  score
# 0   1    A     90
# 1   2    B     85
# 2   3    C     92

# %%
 pd.merge(df1, df2, on='id', how='outer')  # all rows from both
# Out:
#    id name  score
# 0   1    A     90
# 1   2    B     85
# 2   3    C     92

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Data — same MNIST but NOT flattened this time


transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

train_data = datasets.MNIST(root='data', train=True, download=True, transform=transform)
test_data  = datasets.MNIST(root='data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader  = DataLoader(test_data,  batch_size=64, shuffle=False)

print("Data loaded.")
print(f"Image shape: {train_data[0][0].shape}")
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 56.4MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.75MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.34MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 5.77MB/s]
# Data loaded.
# Image shape: torch.Size([1, 28, 28])

# %%
class CNN(nn.Module):
    def __init__(self):
        super().__init__()

        # Convolutional layers
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)

        # Pooling layer
        self.pool = nn.MaxPool2d(2, 2)

        # Fully connected layers
        self.fc1 = nn.Linear(64 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)

        self.relu = nn.ReLU()

    def forward(self, x):
        # x shape: (64, 1, 28, 28)
        x = self.pool(self.relu(self.conv1(x)))  # → (64, 32, 14, 14)
        x = self.pool(self.relu(self.conv2(x)))  # → (64, 64, 7, 7)
        x = x.view(-1, 64 * 7 * 7)              # → (64, 3136) flatten
        x = self.relu(self.fc1(x))               # → (64, 128)
        x = self.fc2(x)                          # → (64, 10)
        return x

model = CNN()
print(model)
print(f"Parameters: {sum(p.numel() for p in model.parameters())}")
# Out:
# CNN(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=3136, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
#   (relu): ReLU()
# )
# Parameters: 421642

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

for epoch in range(5):
    model.train()
    total_loss = 0
    for images, labels in train_loader:
        optimizer.zero_grad()
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"Epoch {epoch+1}, Loss: {total_loss/len(train_loader):.4f}")

# Test accuracy
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        output = model(images)
        predicted = torch.argmax(output, dim=1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

print(f"CNN Accuracy: {100 * correct / total:.2f}%")
# Out:
# Epoch 1, Loss: 0.1354
# Epoch 2, Loss: 0.0441
# Epoch 3, Loss: 0.0294
# Epoch 4, Loss: 0.0219
# Epoch 5, Loss: 0.0157
# CNN Accuracy: 98.61%

# %%
torch.save(model.state_dict(), 'cnn_mnist.pth')
